# %% [markdown]
# # CLAS12 Affinity Calculations
# ### Rowan Kelleher

# %% [markdown]
# #### This Notebook was created for calculating affinity values from CLAS12 MC data, and then analyzing the results

# %% [markdown]
# To use the notebook, first import all necessary imports below:

# %%
from ROOT import TFile,TTree,TCanvas,TH1F,gStyle,TLatex,gPad,TLegend,TLorentzVector,TH2F,TLine,TF1,TBox,RDataFrame,TPad,TF2
import ROOT
import numpy as np
import awkward as awk
import uproot
import pandas as pd
import matplotlib.pyplot as plot
from pandas import read_excel 
from copy import deepcopy
from ipywidgets import *
import logging, os 
logging.disable(logging.WARNING) 
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
print("tf.__version__", tf.__version__)
# Out:
# Welcome to JupyROOT 6.22/06
# tf.__version__ 2.7.4

# %% [markdown]
# This notebook takes in root files and converts them to numpy arrays using uproot.
# On the next line, we pull each tree from the root file (one tree per kinematic variable we binned)

# %% [markdown]
# Here we open the file in uproot and sort the trees into their respective objects

# %%
# up4_file = uproot.concatenate("~/workdir/MCLundAnalysis/OutputFiles/Slurm/March_2/run_1/file_*.root")

up4_file = uproot.open("../OutputFiles/TestFiles/Jan_30/file1.root") #this is where the plots in my prez are from

up4_tree = up4_file["tree_MC"]

# %%
up4_zmin = up4_file["tree_minus_z_h_bins"]
up4_xmin = up4_file["tree_minus_x_bins"]
up4_Mhmin = up4_file["tree_minus_Mh_bins"]
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# <ipython-input-3-166d468c717d> in <module>
# ----> 1 up4_zmin = up4_file["tree_minus_z_h_bins"]
#       2 up4_xmin = up4_file["tree_minus_x_bins"]
#       3 up4_Mhmin = up4_file["tree_minus_Mh_bins"]
#
# /opt/conda/lib/python3.8/site-packages/uproot/reading.py in __getitem__(self, where)
#    2105
#    2106         else:
# -> 2107             return self.key(where).get()
#    2108
#    2109     @property
#
# /opt/conda/lib/python3.8/site-packages/uproot/reading.py in key(self, where)
#    2055             return last
#    2056         elif cycle is None:
# -> 2057             raise uproot.KeyInFileError(
#    2058                 item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2059             )
#
# KeyInFileError: not found: 'tree_minus_z_h_bins' (with any cycle number)
#
#     Available keys: 'tree_z_h_bins;1', 'tree_Mh_bins;1', 'tree_x_bins;1', 'tree_Q2_bins;1', 'tree_qTQ_bins;1', 'tree_MC;1'
#
# in file ../OutputFiles/TestFiles/Jan_30/file1.root

# %% [markdown]
# Now we must fill the arrays. We need to create two that have 6 arrays of length 7 inside them, as these are the arrays for the x and z binnings. This data doesn't include x or z as the center of the bin will be used as the x and z value. For the Mh binning, Mh isn't necessary for calculating Affinity so all the data is already in the array

# %%
#0 is z, 1 is x, 2 is mh
zarrayplus = np.array([np.zeros(7)] * 6)
xarrayplus = np.array([np.zeros(7)] * 6)
Mharrayplus = np.array([np.zeros(7)] * 7)

zarrayminus = np.array([np.zeros(7)] * 6)
xarrayminus = np.array([np.zeros(7)] * 6)
Mharrayminus = np.array([np.zeros(7)] * 7)

xkinematics = np.array(["z_h", "Q2", "pT", "R0", "R1", "R2"])
zkinematics = np.array(["x", "Q2", "pT", "R0", "R1", "R2"])
Mhkinematics = np.array(["x", "z_h", "Q2", "pT", "R0", "R1", "R2"])

#These arrays each hold an array for each variable, meaning that the first bin of variables is in the first index of every kinematics array

#piplus
#z
for i in range(zkinematics.size):
    zarrayplus[i] = up4_zplus[zkinematics[i]].array(library = "np")
#x
for i in range(xkinematics.size):
    xarrayplus[i] = up4_xplus[xkinematics[i]].array(library = "np")
#Mh
for i in range(Mhkinematics.size):
    Mharrayplus[i] = up4_Mhplus[Mhkinematics[i]].array(library = "np")

#piminus    
#z
for i in range(zkinematics.size):
    zarrayminus[i] = up4_zmin[zkinematics[i]].array(library = "np")
#x
for i in range(xkinematics.size):
    xarrayminus[i] = up4_xmin[xkinematics[i]].array(library = "np")
#Mh
for i in range(Mhkinematics.size):
    Mharrayminus[i] = up4_Mhmin[Mhkinematics[i]].array(library = "np")

# %%
print(xarrayminus)

# %% [markdown]
# Now we need to transpose the array. When we filled the arrays with uproot, we put each kinematic in its own array, with those array's indices marking the bin number. Now we want each bin number to have all the kinematics for that bin in one array so we can feed that array to the calculator:

# %%
xarrayplus = np.transpose(xarrayplus)
zarrayplus = np.transpose(zarrayplus)
Mharrayplus = np.transpose(Mharrayplus)

xarrayminus = np.transpose(xarrayminus)
zarrayminus = np.transpose(zarrayminus)
Mharrayminus = np.transpose(Mharrayminus)

# %%
print(xarray)
print(zarray)
print(Mharray)

# %% [markdown]
# This code block uses tensor flow to set up models and predictions based on those models. The user does not need to edit this.

# %%
collinear_region_name = 'collinear'
current_region_name = 'current'
target_region_name = 'target'
TMD_region_name = 'TMD'
soft_region_name = 'soft'
collinear_lable_name = 'collinearaff'
target_lable_name = 'targetaff'
current_lable_name = 'currentaff'
TMD_lable_name = 'tmdaff'
soft_lable_name = 'softaff'

tmd_model_name = '../../SIDIS-Affinity/models/final_%s' % TMD_region_name
tmd_model = tf.keras.models.load_model(tmd_model_name)
target_model_name = '../../SIDIS-Affinity/models/final_%s' % target_region_name
target_model = tf.keras.models.load_model(target_model_name)
collinear_model_name = '../../SIDIS-Affinity/models/final_%s' % collinear_region_name
collinear_model = tf.keras.models.load_model(collinear_model_name)
current_model_name = '../../SIDIS-Affinity/models/final_%s' % current_region_name
current_model = tf.keras.models.load_model(current_model_name)
soft_model_name = '../../SIDIS-Affinity/models/final_%s' % soft_region_name
soft_model = tf.keras.models.load_model(soft_model_name)

# %% [markdown]
# Here we add our binning so that we can use these values in the affinity calculations

# %%
Mhbins = np.linspace(0.3,1.3,7)
xbins = np.array([0.1,0.13,0.16,0.19,0.235,0.3,0.5])
zbins = np.array([0.35,0.43,0.49,0.55,0.62,0.7,0.83])

# %% [markdown]
# Now we create the calculator. Here is how the function works:
# 1. calculator() takes in an array with kinematics, the region (tmd for this study), the name of the variable that we binned, and then the actual value for the center of that bin
# 1. Depening on the name of the binned variable, the function assigns all the necessary kinematics, and fills in the gaps (if applicable) with the center of the bin
# 1. After the kinematics are input, a panda dataframe is created mapping the kinematics to its respective place
# 1. The applicable prediction is then made based on the region (tmd, target, etc)
# 1. The prediction, or affinity value, is returned
# Hence, to calculate affinity yourself, you just need to call the calculator with your array, region, bin name, and bin variable

# %%
def calculator(array, region, binType, binnedVariable = 0):
    if binType == "x":
        z = array[0]
        Q2 = array[1]
        pT = array[2]
        R0max = array[3]
        R1max = array[4]
        R2max = array[5]
        x = binnedVariable
    elif binType == "z":
        x = array[0]
        Q2 = array[1]
        pT = array[2]
        R0max = array[3]
        R1max = array[4]
        R2max = array[5]
        z = binnedVariable
    elif binType == "Mh":
        x = array[0]
        z = array[1]
        Q2 = array[2]
        pT = array[3]
        R0max = array[4]
        R1max = array[5]
        R2max = array[6]
        
    test_features = pd.DataFrame({'pT':pT,'Q2':Q2,'x':x,'z':z,'R0max':R0max,'R1max':R1max,'R2max':R2max},index=[0])

    if region == 'tmd':
        prediction = tmd_model.predict(test_features).flatten()
        
    elif region == 'target':
        prediction = target_model.predict(test_features).flatten()
        
    elif region == 'collinear':
        prediction = collinear_model.predict(test_features).flatten()

    elif region == 'soft':
        prediction = soft_model.predict(test_features).flatten()

    else:
        prediction = current_model.predict(test_features).flatten()

    return prediction[0] #returns affinity value

# %%
colxaffinityplus = np.zeros(7)
colzaffinityplus = np.zeros(7)
colMhaffinityplus = np.zeros(7)
TMDxaffinityplus = np.zeros(7)
TMDzaffinityplus = np.zeros(7)
TMDMhaffinityplus = np.zeros(7)
Currentxaffinityplus = np.zeros(7)
Currentzaffinityplus = np.zeros(7)
CurrentMhaffinityplus = np.zeros(7)

colxaffinityminus = np.zeros(7)
colzaffinityminus = np.zeros(7)
colMhaffinityminus = np.zeros(7)
TMDxaffinityminus = np.zeros(7)
TMDzaffinityminus = np.zeros(7)
TMDMhaffinityminus = np.zeros(7)
Currentxaffinityminus = np.zeros(7)
Currentzaffinityminus = np.zeros(7)
CurrentMhaffinityminus = np.zeros(7)

region = "collinear"
region2 = "tmd"
region3 = "current"
for i in range(7):
    colzaffinityplus[i] = calculator(zarrayplus[i], region, "z", zbins[i])
    colxaffinityplus[i] = calculator(xarrayplus[i], region, "x", xbins[i])
    colMhaffinityplus[i] = calculator(Mharrayplus[i], region, "Mh")
    TMDzaffinityplus[i] = calculator(zarrayplus[i], region2, "z", zbins[i])
    TMDxaffinityplus[i] = calculator(xarrayplus[i], region2, "x", xbins[i])
    TMDMhaffinityplus[i] = calculator(Mharrayplus[i], region2, "Mh")
    Currentzaffinityplus[i] = calculator(zarrayplus[i], region3, "z", zbins[i])
    Currentxaffinityplus[i] = calculator(xarrayplus[i], region3, "x", xbins[i])
    CurrentMhaffinityplus[i] = calculator(Mharrayplus[i], region3, "Mh")
    
    colzaffinityminus[i] = calculator(zarrayminus[i], region, "z", zbins[i])
    colxaffinityminus[i] = calculator(xarrayminus[i], region, "x", xbins[i])
    colMhaffinityminus[i] = calculator(Mharrayminus[i], region, "Mh")
    TMDzaffinityminus[i] = calculator(zarrayminus[i], region2, "z", zbins[i])
    TMDxaffinityminus[i] = calculator(xarrayminus[i], region2, "x", xbins[i])
    TMDMhaffinityminus[i] = calculator(Mharrayminus[i], region2, "Mh")
    Currentzaffinityminus[i] = calculator(zarrayminus[i], region3, "z", zbins[i])
    Currentxaffinityminus[i] = calculator(xarrayminus[i], region3, "x", xbins[i])
    CurrentMhaffinityminus[i] = calculator(Mharrayminus[i], region3, "Mh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9d6b4a9c1575> in <module>
#      23 region3 = "current"
#      24 for i in range(7):
# ---> 25     colzaffinityplus[i] = calculator(zarrayplus[i], region, "z", zbins[i])
#      26     colxaffinityplus[i] = calculator(xarrayplus[i], region, "x", xbins[i])
#      27     colMhaffinityplus[i] = calculator(Mharrayplus[i], region, "Mh")
#
# NameError: name 'zarrayplus' is not defined

# %%
#print(zaffinity)
#print(Mhaffinity)
#print(xaffinity)

# %%
fig, (ax1, ax2, ax3) = plot.subplots(1, 3, figsize = (20, 5))
fig.suptitle("Pi+ Affinity in the Collinear region")
ax1.set(ylabel = "Affinity")
ax1.scatter(Mhbins, colMhaffinityplus)
ax1.axhline(y=0, color="gray", lw = 1)
ax1.set_title("Mh binning")
ax1.set(xlabel = "Mh (GeV)")
ax2.scatter(xbins, colxaffinityplus)
ax2.axhline(y=0, color="gray", lw = 1)
ax2.set_title("x binning")
ax2.set(xlabel = "x")
ax3.scatter(zbins, colzaffinityplus)
ax3.axhline(y=0, color="gray", lw = 1)
ax3.set_title("z_h binning")
ax3.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]

# %%
fig, (ax1, ax2, ax3) = plot.subplots(1, 3, figsize = (20, 5))
fig.suptitle("Pi- Affinity in the Collinear region")
ax1.set(ylabel = "Affinity")
ax1.scatter(Mhbins, colMhaffinityminus)
ax1.axhline(y=0, color="gray", lw = 1)
ax1.set_title("Mh binning")
ax1.set(xlabel = "Mh (GeV)")
ax2.scatter(xbins, colxaffinityminus)
ax2.axhline(y=0, color="gray", lw = 1)
ax2.set_title("x binning")
ax2.set(xlabel = "x")
ax3.scatter(zbins, colzaffinityminus)
ax3.axhline(y=0, color="gray", lw = 1)
ax3.set_title("z_h binning")
ax3.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]

# %%
fig2, (ax12, ax22, ax32) = plot.subplots(1, 3, figsize = (20, 5))
fig2.suptitle("Pi+ Affinity in the TMD region")
ax12.set(ylabel = "Affinity")
ax12.scatter(Mhbins, TMDMhaffinityplus)
ax12.axhline(y=0, color="gray", lw = 1)
ax12.set_title("Mh binning")
ax12.set(xlabel = "Mh (GeV)")
ax22.scatter(xbins, TMDxaffinityplus)
ax22.axhline(y=0, color="gray", lw = 1)
ax22.set_title("x binning")
ax22.set(xlabel = "x")
ax32.scatter(zbins, TMDzaffinityplus)
ax32.axhline(y=0, color="gray", lw = 1)
ax32.set_title("z_h binning")
ax32.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]

# %%
fig2, (ax12, ax22, ax32) = plot.subplots(1, 3, figsize = (20, 5))
fig2.suptitle("Pi- Affinity in the TMD region")
ax12.set(ylabel = "Affinity")
ax12.scatter(Mhbins, TMDMhaffinityminus)
ax12.axhline(y=0, color="gray", lw = 1)
ax12.set_title("Mh binning")
ax12.set(xlabel = "Mh (GeV)")
ax22.scatter(xbins, TMDxaffinityminus)
ax22.axhline(y=0, color="gray", lw = 1)
ax22.set_title("x binning")
ax22.set(xlabel = "x")
ax32.scatter(zbins, TMDzaffinityminus)
ax32.axhline(y=0, color="gray", lw = 1)
ax32.set_title("z_h binning")
ax32.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]

# %%
fig3, (ax13, ax23, ax33) = plot.subplots(1, 3, figsize = (20, 5))
fig3.suptitle("Pi+ Affinity in the Current region")
ax13.set(ylabel = "Affinity")
ax13.scatter(Mhbins, CurrentMhaffinityplus)
ax13.axhline(y=0, color="gray", lw = 1)
ax13.set_title("Mh binning")
ax13.set(xlabel = "Mh (GeV)")
ax23.scatter(xbins, Currentxaffinityplus)
ax23.axhline(y=0, color="gray", lw = 1)
ax23.set_title("x binning")
ax23.set(xlabel = "x")
ax33.scatter(zbins, Currentzaffinityplus)
ax33.axhline(y=0, color="gray", lw = 1)
ax33.set_title("z_h binning")
ax33.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]

# %%
fig3, (ax13, ax23, ax33) = plot.subplots(1, 3, figsize = (20, 5))
fig3.suptitle("Pi- Affinity in the Current region")
ax13.set(ylabel = "Affinity")
ax13.scatter(Mhbins, CurrentMhaffinityminus)
ax13.axhline(y=0, color="gray", lw = 1)
ax13.set_title("Mh binning")
ax13.set(xlabel = "Mh (GeV)")
ax23.scatter(xbins, Currentxaffinityminus)
ax23.axhline(y=0, color="gray", lw = 1)
ax23.set_title("x binning")
ax23.set(xlabel = "x")
ax33.scatter(zbins, Currentzaffinityminus)
ax33.axhline(y=0, color="gray", lw = 1)
ax33.set_title("z_h binning")
ax33.set(xlabel = "z_h")
# Out:
# [Text(0.5, 0, 'z_h')]
