# %%
import uproot as up

# %%
f = up.open("root://dtn-eic.jlab.org//work/eic2/mc/PYTHIA_6.5/DIS/pythia_e-p_10x50_Q2_100k_msel2_DIS.root")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/fsspec/registry.py:242, in get_filesystem_class(protocol)
#     241 try:
# --> 242     register_implementation(protocol, _import_class(bit["class"]))
#     243 except ImportError as e:
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/registry.py:277, in _import_class(fqp)
#     276 is_s3 = mod == "s3fs"
# --> 277 mod = importlib.import_module(mod)
#     278 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File /opt/conda/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# ...
